# %%
import os 
import certifi
import requests
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.tools import tool
from langchain_community.tools.tavily_search import TavilySearchResults
from langchainhub import Client

# %%
from langchain.agents import create_agent

# %%
#Load ENV Variable 

os.environ["SSL_CERT_FILE"] = certifi.where()
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

# %%
search_tool = TavilySearchResults(max_results=2)

# %%
@tool
def get_weather_data(city: str) -> str:
    """"
    Fetch curren weather information fro a city
    
    """

    url = (
        f"https://api.weatherstack.com/current?"
        f"access_key={WEATHER_API_KEY}&query={city}"
    )

    response = requests.get(url)

    data = response.json()

    if "current" not in data:
        return f"Could not fetch weather data for {city}"


    return (
        f"City: {city}\n"
        f"Temperature: {data['current']['Temperature']}\n"
        f"Weather: {data['current']['weather_descriptions'[0]]}\n"
        f"Humidity: {data['current']['humidity']}%"
    )

# %%
search_tool.invoke("How much Spider man brand new day box office collection so far")
# Out:
# [{'title': 'Spider-Man: Brand New Day (2026) - Box Office and Financial Information',
#   'url': 'https://www.the-numbers.com/movie/Spider-Man-Brand-New-Day-(2026)',
# ...

# %%
llm = ChatOpenAI(
    model = "gpt-3.5-turbo",
    temperature=0,
    api_key=OPENAI_API_KEY
)

# %%
response = llm.invoke("waht year it is")
response
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 response = llm.invoke("waht year it is")
#       2 response
#
# File ~/Agentic AI/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
# ...

# %%
#prompt

prompt = hub.pull("hwchase17/react")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       1 #prompt
#       2 from langsmith import Client
#       3
#       4 client = Client()
# ----> 5 prompt = client.pull_prompt("hwchase17/react")
#       6
#       7 print(prompt)
#
# File ~/Agentic AI/.venv/lib/python3.14/site-packages/langsmith/client.py:10108, in Client.pull_prompt(self, prompt_identifier, include_model, secrets, secrets_from_env, skip_cache, dangerously_pull_public_prompt)
#   10104             [GHSA-c67j-w6g6-q2cm](https://github.com/langchain-ai/langchain/security/advisories/GHSA-c67j-w6g6-q2cm)
#   10105             in the `langchain-core` package which this method (but not the entire
#   10106             langsmith package) depends on.
#   10107         """
# > 10108         prompt_object = self.pull_prompt_commit(
#   10109             prompt_identifier,
# ...

# %%
tools = [search_tool]

# %%
agent = create_agent(
    llm=llm,
    tools=tools,
    prompt=prompt
)

# %%
agent_executor = AgentExecutor(
    agent=agent,
    tools=tools,
    verbise=True
)

# %%
response = agent_executor.invoke({
    "input":(
        "Find the capital of india"
      
    )
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 response = agent_executor.invoke({
#       2     "input":(
#       3         "Find the capital of india"
#       4
#
# NameError: name 'agent_executor' is not defined

# %%
print(response["output"])
